# %% [markdown]
# # Supplementary Figure 7
#
# **Fine tuning DenseNet121 to classify *F. oxysporum* spores as germinated or ungerminated**
#
# - **Is** — a screenshot of the running Mycol app; nothing here can redraw it
# - **Does** — copies `assets/Figure_S7.png` into `output/`
# - **Panels** — Plotly figures stored in the session: **a** `densenet_training_losses.json` · **b** `densenet_training_metrics.json`
# - **Kernel** — `mycol_colonies_env`, run top to bottom

# %%
import shutil
from pathlib import Path

from IPython.display import display
from PIL import Image

OUTPUT = Path("output")
OUTPUT.mkdir(exist_ok=True)
out = shutil.copy2("assets/Figure_S7.png", OUTPUT / "Figure_S7.png")

im = Image.open(out)
print(f"wrote {out}  {im.width} x {im.height} px, {Path(out).stat().st_size:,} B")
im.thumbnail((900, 900))
display(im.convert("RGB"))
